# %% [markdown]
# # Baseline: RNN Model on real world data

# %%
import tensorflow.keras as keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

np.random.seed(1)

sns.set_style("darkgrid")
# Out:
# 2021-12-22 19:10:52.196769: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-12-22 19:10:52.196826: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
df = pd.read_csv('prepared_dataset.csv')

# %% [markdown]
# ## Exploring the dataset

# %%
df.shape
# Out:
# (5012, 10)

# %%
df.head()
# Out:
#    Unnamed: 0  Car1  Car2  Car3  Car4  Car5  Car6  Car7  Car8  Car9
# 0           0  77.0  52.0  51.0  51.0  34.0  26.0  29.0  31.0  23.0
# 1           1  77.0  52.0  52.0  44.0  32.0  26.0  28.0  32.0  21.0
# 2           2  77.0  53.0  49.0  44.0  34.0  27.0  28.0  31.0  22.0
# 3           3  77.0  52.0  49.0  53.0  36.0  31.0  24.0  30.0  22.0
# 4           4  77.0  52.0  49.0  45.0  37.0  32.0  26.0  30.0  21.0

# %%
df.describe()
# Out:
#         Unnamed: 0         Car1         Car2         Car3        Car4  \
# count  5012.000000  5012.000000  5012.000000  5012.000000  5012.00000
# mean   2505.500000    75.943724    52.202754    49.121732    42.10038
# std    1446.984105     1.489009     1.687287     2.071065     2.48108
# min       0.000000    67.000000    45.000000    40.000000    31.00000
# 25%    1252.750000    75.000000    51.000000    48.000000    40.00000
# 50%    2505.500000    76.000000    52.000000    49.000000    42.00000
# 75%    3758.250000    77.000000    54.000000    51.000000    44.00000
# max    5011.000000    80.000000    56.000000    54.000000    54.00000
#
#               Car5         Car6         Car7         Car8         Car9
# count  5012.000000  5012.000000  5012.000000  5012.000000  5012.000000
# mean     33.067452    31.937937    29.929555    26.673119    21.401317
# std       2.927624     3.314419     4.362906     2.778333     2.500128
# min      15.000000    11.000000    12.000000    11.000000     7.000000
# 25%      31.000000    30.000000    28.000000    25.000000    20.000000
# 50%      33.000000    32.000000    30.000000    27.000000    21.000000
# 75%      35.000000    34.000000    33.000000    29.000000    23.000000
# max      43.000000    44.000000    48.000000    40.000000    30.000000

# %%
df.count()
# Out:
# Unnamed: 0    5012
# Car1          5012
# Car2          5012
# Car3          5012
# Car4          5012
# Car5          5012
# Car6          5012
# Car7          5012
# Car8          5012
# Car9          5012
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#    Car1  Car2  Car3  Car4  Car5  Car6  Car7  Car8  Car9
# 0  77.0  52.0  51.0  51.0  34.0  26.0  29.0  31.0  23.0
# 1  77.0  52.0  52.0  44.0  32.0  26.0  28.0  32.0  21.0
# 2  77.0  53.0  49.0  44.0  34.0  27.0  28.0  31.0  22.0
# 3  77.0  52.0  49.0  53.0  36.0  31.0  24.0  30.0  22.0
# 4  77.0  52.0  49.0  45.0  37.0  32.0  26.0  30.0  21.0

# %%
df['Car1'].unique()
# Out:
# array([77.        , 73.        , 74.        , 75.        , 76.        ,
#        78.        , 72.        , 69.        , 71.        , 70.        ,
#        67.        , 79.        , 80.        , 75.94491018])

# %% [markdown]
# ## Visualizing the dataset

# %%
cols = df.columns

# %%
cols = list(cols)

# %%
cols
# Out:
# ['Car1', 'Car2', 'Car3', 'Car4', 'Car5', 'Car6', 'Car7', 'Car8', 'Car9']

# %%
values = df.to_numpy()
i = 1

plt.figure(figsize=(25, 35), dpi=88)
for col in cols:
  plt.subplot(len(cols), 1, i)
  plt.plot(values[:, cols.index(col)])
  i+=1

plt.show()

# %%
values
# Out:
# array([[77.        , 52.        , 51.        , ..., 29.        ,
#         31.        , 23.        ],
#        [77.        , 52.        , 52.        , ..., 28.        ,
#         32.        , 21.        ],
#        [77.        , 53.        , 49.        , ..., 28.        ,
#         31.        , 22.        ],
#        ...,
#        [75.94491018, 52.20339321, 49.12315369, ..., 29.92914172,
#         26.6744511 , 21.40259481],
#        [67.        , 45.        , 40.        , ..., 12.        ,
#         11.        ,  7.        ],
#        [80.        , 56.        , 54.        , ..., 48.        ,
#         40.        , 30.        ]])

# %%
values[:]
# Out:
# array([[77.        , 52.        , 51.        , ..., 29.        ,
#         31.        , 23.        ],
#        [77.        , 52.        , 52.        , ..., 28.        ,
#         32.        , 21.        ],
#        [77.        , 53.        , 49.        , ..., 28.        ,
#         31.        , 22.        ],
#        ...,
#        [75.94491018, 52.20339321, 49.12315369, ..., 29.92914172,
#         26.6744511 , 21.40259481],
#        [67.        , 45.        , 40.        , ..., 12.        ,
#         11.        ,  7.        ],
#        [80.        , 56.        , 54.        , ..., 48.        ,
#         40.        , 30.        ]])

# %%
values.shape
# Out:
# (5012, 9)

# %% [markdown]
# ## Preparing data for LSTM

# %% [markdown]
# ## Timeseries Transformation

# %% [markdown]
# ## Time Difference

# %%
df = df.diff()

# %%
df = df.iloc[1:, :]

# %%
LSTMvalues = df.to_numpy()
i = 1

plt.figure(figsize=(25, 35), dpi=88)
for col in cols:
  plt.subplot(len(cols), 1, i)
  plt.plot(values[:, cols.index(col)])
  i+=1

plt.show()

# %% [markdown]
# ### Now the data is reasonably stationary

# %% [markdown]
# ### Train Test Split

# %%
df.shape
# Out:
# (5011, 9)

# %%
0.9*5011
# Out:
# 4509.900000000001

# %%
train_dataset = df.iloc[:4509]
test_dataset = df.iloc[4509:]

# %%
train_dataset.shape
# Out:
# (4509, 9)

# %%
test_dataset.shape
# Out:
# (502, 9)

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import RobustScaler

f_transformer = RobustScaler()

f_transformer = f_transformer.fit(train_dataset.to_numpy())

normalized_train_dataset = f_transformer.transform(train_dataset.to_numpy())
normalized_test_dataset = f_transformer.transform(test_dataset.to_numpy())

# %%
def create_dataset(data, steps):
  features, labels = [], []
  for i in range(len(data)-steps):
    data_seq = data[i: i+steps, :]
    features.append(data_seq)

    seq_label = data[i+steps, :]
    labels.append(seq_label)

  return np.array(features), np.array(labels)

# %%
TIME_STEPS = 15

train_features, train_labels = create_dataset(normalized_train_dataset, TIME_STEPS)
test_features, test_labels = create_dataset(normalized_test_dataset, TIME_STEPS)

# %%
print(train_features.shape, train_labels.shape)
print(test_features.shape, test_labels.shape)
# Out:
# (4494, 15, 9) (4494, 9)
# (487, 15, 9) (487, 9)

# %% [markdown]
# ## Data should be in the shape of [samples, timesteps, n_features]

# %% [markdown]
# ## LSTM Model

# %%
model = keras.models.Sequential()
model.add(LSTM
    keras.layers.RNN(
          50, 
          input_shape=(train_features.shape[1], train_features.shape[2])
        )
    )
model.add(keras.layers.Dense(9))

model.compile(optimizer='adam', loss=['mse', 'mae'])
# Out:
# 2021-12-22 18:53:44.054915: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-12-22 18:53:44.055021: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-22 18:53:44.055137: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (home): /proc/driver/nvidia/version does not exist

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50)                12000
# _________________________________________________________________
# dense (Dense)                (None, 9)                 459
# =================================================================
# Total params: 12,459
# Trainable params: 12,459
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_features, train_labels, batch_size=64, epochs=50, shuffle=False, validation_split=0.1)
# Out:
# 2021-12-22 18:54:10.262043: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-22 18:54:10.275006: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2691010000 Hz
# Epoch 1/50
# 64/64 [==============================] - 7s 22ms/step - loss: 0.9453 - val_loss: 0.7858
# Epoch 2/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.8282 - val_loss: 0.6929
# Epoch 3/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7543 - val_loss: 0.6620
# Epoch 4/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7370 - val_loss: 0.6496
# Epoch 5/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7292 - val_loss: 0.6473
# Epoch 6/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7245 - val_loss: 0.6474
# Epoch 7/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7210 - val_loss: 0.6481
# Epoch 8/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7180 - val_loss: 0.6488
# Epoch 9/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7153 - val_loss: 0.6494
# Epoch 10/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7129 - val_loss: 0.6503
# Epoch 11/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7106 - val_loss: 0.6515
# Epoch 12/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7084 - val_loss: 0.6530
# Epoch 13/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7063 - val_loss: 0.6547
# Epoch 14/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7042 - val_loss: 0.6563
# Epoch 15/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7021 - val_loss: 0.6580
# Epoch 16/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7000 - val_loss: 0.6597
# Epoch 17/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6979 - val_loss: 0.6615
# Epoch 18/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6958 - val_loss: 0.6634
# Epoch 19/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6938 - val_loss: 0.6654
# Epoch 20/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6918 - val_loss: 0.6676
# Epoch 21/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6898 - val_loss: 0.6701
# Epoch 22/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6878 - val_loss: 0.6728
# Epoch 23/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6858 - val_loss: 0.6755
# Epoch 24/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6837 - val_loss: 0.6782
# Epoch 25/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6814 - val_loss: 0.6806
# Epoch 26/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6791 - val_loss: 0.6831
# Epoch 27/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6768 - val_loss: 0.6860
# Epoch 28/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6743 - val_loss: 0.6888
# Epoch 29/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6714 - val_loss: 0.6909
# Epoch 30/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6683 - val_loss: 0.6923
# Epoch 31/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6653 - val_loss: 0.6937
# Epoch 32/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6623 - val_loss: 0.6953
# Epoch 33/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6594 - val_loss: 0.6971
# Epoch 34/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6566 - val_loss: 0.6991
# Epoch 35/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6537 - val_loss: 0.7013
# Epoch 36/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6508 - val_loss: 0.7041
# Epoch 37/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6480 - val_loss: 0.7075
# Epoch 38/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6452 - val_loss: 0.7120
# Epoch 39/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6424 - val_loss: 0.7179
# Epoch 40/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6398 - val_loss: 0.7254
# Epoch 41/50
# 64/64 [==============================] - 1s 13ms/step - loss: 0.6374 - val_loss: 0.7358
# Epoch 42/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6354 - val_loss: 0.7507
# Epoch 43/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6339 - val_loss: 0.7645
# Epoch 44/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6327 - val_loss: 0.7571
# Epoch 45/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6325 - val_loss: 0.7367
# Epoch 46/50
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6320 - val_loss: 0.7289
# Epoch 47/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6319 - val_loss: 0.7316
# Epoch 48/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6300 - val_loss: 0.7405
# Epoch 49/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6302 - val_loss: 0.7507
# Epoch 50/50
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6263 - val_loss: 0.7683

# %%
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## Choosing 25 Epochs to re-train the model

# %%
model = keras.models.Sequential()
model.add(
    keras.layers.LSTM(
          50, 
          input_shape=(train_features.shape[1], train_features.shape[2])
        )
    )
model.add(keras.layers.Dense(9))

model.compile(optimizer='adam', loss=['mse', 'mae'])


history = model.fit(train_features, train_labels, batch_size=64, epochs=25, shuffle=False, validation_split=0.1)
# Out:
# Epoch 1/25
# 64/64 [==============================] - 3s 24ms/step - loss: 0.9646 - val_loss: 0.8010
# Epoch 2/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.8416 - val_loss: 0.6980
# Epoch 3/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7606 - val_loss: 0.6640
# Epoch 4/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7396 - val_loss: 0.6549
# Epoch 5/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7318 - val_loss: 0.6553
# Epoch 6/25
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7279 - val_loss: 0.6526
# Epoch 7/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7246 - val_loss: 0.6527
# Epoch 8/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7215 - val_loss: 0.6533
# Epoch 9/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7186 - val_loss: 0.6538
# Epoch 10/25
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7160 - val_loss: 0.6545
# Epoch 11/25
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7136 - val_loss: 0.6555
# Epoch 12/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7114 - val_loss: 0.6569
# Epoch 13/25
# 64/64 [==============================] - 1s 12ms/step - loss: 0.7092 - val_loss: 0.6586
# Epoch 14/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7070 - val_loss: 0.6608
# Epoch 15/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7049 - val_loss: 0.6631
# Epoch 16/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7027 - val_loss: 0.6656
# Epoch 17/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.7005 - val_loss: 0.6682
# Epoch 18/25
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6983 - val_loss: 0.6710
# Epoch 19/25
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6961 - val_loss: 0.6738
# Epoch 20/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6939 - val_loss: 0.6767
# Epoch 21/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6916 - val_loss: 0.6797
# Epoch 22/25
# 64/64 [==============================] - 1s 12ms/step - loss: 0.6892 - val_loss: 0.6829
# Epoch 23/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6869 - val_loss: 0.6860
# Epoch 24/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6845 - val_loss: 0.6891
# Epoch 25/25
# 64/64 [==============================] - 1s 11ms/step - loss: 0.6821 - val_loss: 0.6922

# %%
print(history.history['val_loss'][-1])
# Out:
# 0.6921823620796204

# %%
predictions = model.predict(test_features)

# %%
predictions.shape
# Out:
# (487, 9)

# %%
test_labels.shape
# Out:
# (487, 9)

# %%
i = 1

plt.figure(figsize=(20, 55), dpi=88)

for col in cols:
  plt.title('LSTM - Comparison between Actual and Predicted values')

  plt.subplot(len(cols), 1, i)
  plt.plot(test_labels[:, cols.index(col)], color='blue', label='Actual')
  plt.plot(predictions[:, cols.index(col)], color='red', label='Predicted')
  plt.legend()
  i+=1
  if i == 4:
    break
    

plt.xlabel('Time')
plt.show()
