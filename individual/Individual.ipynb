# vehicle_8   1400.0   8.029671  0.380007   7.38   7.6900   8.040   8.3500
# vehicle_9   1400.0  13.348021  0.381648  11.38  13.0200  13.350  13.6800
#
#               max
# vehicle_0   14.00
# vehicle_1    9.52
# vehicle_10  13.00
# vehicle_11  14.00
# vehicle_12  12.00
# vehicle_13   7.18
# vehicle_14  12.00
# vehicle_15   5.35
# vehicle_16   4.12
# vehicle_17   4.08
# vehicle_18  12.00
# vehicle_19  13.00
# vehicle_2   12.00
# vehicle_3   13.00
# vehicle_4   10.46
# vehicle_5   14.00
# vehicle_6   12.14
# vehicle_7   13.00
# vehicle_8    8.68
# vehicle_9   14.00

# %%
from sklearn.preprocessing import Normalizer
import pandas as pd
from typing import List

class VectorNormalizer:
    """
    provided methods to fit, transform and inverse transform 2-D arrays 
    transformation applied: x/ L2 norm of X =>
    """
    def __init__(self) -> None:
        """
        intialize attributes
        """
        self.norms = []
        self.inverse_transformed = []
        self.transformed = []

    def fit(self, dataframe) -> List[int]:
        """
        calculates norms of all row vectors in the dataframe

        returns: list of norms
        """
        for item in dataframe.to_numpy():
            self.norms.append(np.sqrt(np.sum(np.square(item))))
        
        return self.norms

    def transform(self, dataframe) -> pd.DataFrame():
        """
        performs vector normalization

        returns: original dataframe after normalization
        """        
        for idx, item in enumerate(dataframe.to_numpy()):
            self.transformed.append(item/self.norms[idx])
        
        return pd.DataFrame(self.transformed)


    def inverse_transform(self, inverse_transformed_df) -> pd.DataFrame():
        """
        calculates product of norms of all row vectors with row vectors in the dataframe

        returns: original dataframe after transformations
        
        """
        for idx, item in enumerate(inverse_transformed_df.to_numpy()):
            self.inverse_transformed.append(item * self.norms[idx])
        
        return pd.DataFrame(self.inverse_transformed)


scaler = VectorNormalizer()
norms = scaler.fit(df)

# %%
df_scale = scaler.transform(df_speed)

# %%
model_1 = df.loc[:, 'vehicle_0']
model_2 = df.loc[:, 'vehicle_1']
model_3 = df.loc[:, 'vehicle_2']
model_4 = df.loc[:, 'vehicle_3']

model_5 = df.loc[:, 'vehicle_4']
model_6 = df.loc[:, 'vehicle_5']
model_7 = df.loc[:, 'vehicle_6']
model_8 = df.loc[:, 'vehicle_7']

model_9 = df.loc[:, 'vehicle_8']

model_10 = df.loc[:, 'vehicle_9']
model_11 = df.loc[:, 'vehicle_10']
model_12 = df.loc[:, 'vehicle_11']
model_13 = df.loc[:, 'vehicle_12']

model_14 = df.loc[:, 'vehicle_13']
model_15 = df.loc[:, 'vehicle_14']
model_16 = df.loc[:, 'vehicle_15']
model_17 = df.loc[:, 'vehicle_16']

model_18 = df.loc[:, 'vehicle_17']
model_19 = df.loc[:, 'vehicle_18']
model_20 = df.loc[:, 'vehicle_19']
